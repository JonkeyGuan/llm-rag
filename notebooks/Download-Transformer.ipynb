# %%
# !git config --global credential.helper store
# !pip install --upgrade huggingface_hub
# !huggingface-cli login --token $HF_TOKEN --add-to-git-credential
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Token is valid (permission: read).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /opt/app-root/src/.cache/huggingface/token
# Login successful

# %%
# !git clone https://huggingface.co/nomic-ai/nomic-embed-text-v1

# %%
# !git clone https://huggingface.co/nomic-ai/nomic-bert-2048

# %%
# !pip install -q einops==0.7.0 langchain==0.1.9 pypdf==4.0.2 pymilvus==2.3.6 sentence-transformers==2.5.0
# Out:
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
from langchain.embeddings import HuggingFaceEmbeddings

# %%
model_path = "./nomic-embed-text-v1"

embeddings = HuggingFaceEmbeddings(
    model_name=model_path,
    model_kwargs={'trust_remote_code': True},
    show_progress=True
)

texts = ["This is a test sentence.", "Here is another one."]
embeddings_list = embeddings.embed_documents(texts)

print(embeddings_list)
# Out:
# <All keys matched successfully>
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
